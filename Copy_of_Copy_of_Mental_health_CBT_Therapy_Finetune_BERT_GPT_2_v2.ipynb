# %% [markdown]
# <a href="https://colab.research.google.com/github/rajagopalmotivate/DeepLearningforSocietal/blob/main/Copy_of_Copy_of_Mental_health_CBT_Therapy_Finetune_BERT_GPT_2_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #  Mental health expert fine tunes a GPT-2 model

# %%
#%tensorflow_version 1.x

# !pip install -q gpt-2-simple
import gpt_2_simple as gpt2
from datetime import datetime
from google.colab import files
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for gpt-2-simple (setup.py) ... done

# %% [markdown]
# ## Downloading GPT-2
#
# The default query returns 1.3MB of data, so probably should only use `124M` GPT-2 to finetune. If working with more Reddity data, then migrate to `355M`.

# %%
gpt2.download_gpt2(model_name="124M")
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 3.67Git/s]
# Fetching encoder.json: 1.05Mit [00:01, 573kit/s]
# Fetching hparams.json: 1.05Mit [00:00, 4.40Git/s]
# Fetching model.ckpt.data-00000-of-00001: 498Mit [00:54, 9.22Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 423Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:01, 864kit/s]
# Fetching vocab.bpe: 1.05Mit [00:01, 845kit/s]

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ## Mental health professional provides her input here.

# %%
LISTOFDEPRESSIONSITATION = [ 'lost my job ', 'i got fired ', 'i am unemployed ' , 'i am unable to pay bill ']

# %%
LISTOFDEPRESSIONTHOUGHTS = [ 'i am depressed', 'i feel so low', 'i am mentally depressed' , 'i am so much in sorrow', 'i am so dull',  'i am tired of life' , 'i am depressed all night', 'i am so low' ]

# %%
LISTOFCBTBELFIFS = ['i am smart', 'i am good', 'i am well educated', 'i am cool', 'i am well qualified', 'i am intelligent', 'i have managed worser things than this', 'i am quite smart ', ' i have lot of hope on the future', 'i have saved enough', 'i am very smart', 'i have a good reputation', ' i have a supportive family', 'my firends say i am smart', 'my family say i am smart compared to others', 'my friend is kind to me', 'my family is so supportive']

# %%
LISTOFCBTBELFIFSCONNECTIONS = [' . i remember', ', but fortunately ', ' , but luckily for me ', ', ' , ' . I know ', ' .Let me recollect that ', ' . Let me keep remembering that ', ' . Let me feel thankful that ', ' . ']

# %%
import random

# %%
def getaRandomword(mylistofword):
  return mylistofword[random.randint(0, len(mylistofword) -1) ]

# %%
def getaRandomsequence(seq1, seq2):
  concatsimilarmeaningwords = ['  ', ' ', ' and ']
  randomnumber = random.randint(0,1)
  ans = ""
  if randomnumber == 0:
    ans = seq1 +  getaRandomword(concatsimilarmeaningwords) + seq2
  else :
    ans = seq2 + getaRandomword(concatsimilarmeaningwords) + seq1
  return ans

# %%
aLISTOFDEPRESSIONSITATION = getaRandomword(LISTOFDEPRESSIONSITATION)
aLISTOFDEPRESSIONTHOUGHTS = getaRandomword(LISTOFDEPRESSIONTHOUGHTS)
aLISTOFCBTBELFIFS = getaRandomword(LISTOFCBTBELFIFS)
aLISTOFCBTBELFIFSCONNECTIONS = getaRandomword(LISTOFCBTBELFIFSCONNECTIONS)

# %%
asentance =  aLISTOFDEPRESSIONTHOUGHTS +  " "+ aLISTOFCBTBELFIFSCONNECTIONS + " " + aLISTOFCBTBELFIFS

# %%
asentance
# Out:
# 'i am mentally depressed  .  i am good'

# %%
import pandas as pd
df = pd.DataFrame([asentance])

for i in range(4098):
  aLISTOFDEPRESSIONSITATION = getaRandomword(LISTOFDEPRESSIONSITATION)
  aLISTOFDEPRESSIONTHOUGHTS = getaRandomword(LISTOFDEPRESSIONTHOUGHTS)
  aLISTOFCBTBELFIFS = getaRandomword(LISTOFCBTBELFIFS)
  aLISTOFCBTBELFIFSCONNECTIONS = getaRandomword(LISTOFCBTBELFIFSCONNECTIONS)
  asentance = getaRandomsequence(aLISTOFDEPRESSIONSITATION , aLISTOFDEPRESSIONTHOUGHTS) +  " "+ aLISTOFCBTBELFIFSCONNECTIONS + " " + aLISTOFCBTBELFIFS


  #asentance =   " "+ aLISTOFCBTBELFIFSCONNECTIONS + " " + aLISTOFCBTBELFIFS
  dfnew = pd.DataFrame([asentance])
  df = df.append(dfnew)
# Out:
# Streaming output truncated to the last 5000 lines.
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# ...
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)
# <ipython-input-14-c7041df9c191>:14: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(dfnew)

# %%
df.to_csv('myDataFrame.csv', index=False, header=False  )

# %%
from google.colab import files
files.download('myDataFrame.csv')

# %% [markdown]
# ## This mental health professional can upload her experiences in a CSV file
#
# A single-column CSV is expected.

# %%
# file upload

# %%
file_name = "myDataFrame.csv"

# %% [markdown]
# ## Mental health professional trains the GPT-2 model
#
# Providing a single-column CSV will automatically add `<|startoftext|>` and `<|endoftext|>` tokens appropriately.
#
# Short form text is more likely to overfit, so train it with fewer steps than you would for longform content.

# %%
sess = gpt2.start_tf_sess()

gpt2.finetune(sess,
              dataset=file_name,
              model_name='124M',
              steps=100,
              restore_from='fresh',
              run_name='run2',
              print_every=10,
              sample_every=90
              )
# Out:
# Loading checkpoint models/124M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:00<00:00, 87.66it/s]
# dataset has 144878 tokens
# Training...
# [10 | 28.67] loss=0.66 avg=0.66
# [20 | 50.55] loss=0.43 avg=0.55
# [30 | 73.21] loss=0.36 avg=0.48
# [40 | 96.93] loss=0.33 avg=0.44
# [50 | 120.29] loss=0.32 avg=0.42
# [60 | 143.33] loss=0.31 avg=0.40
# [70 | 166.50] loss=0.31 avg=0.39
# [80 | 189.73] loss=0.30 avg=0.38
# [90 | 213.09] loss=0.31 avg=0.37
# ======== SAMPLE 1 ========
# texttext/i am tired of life   . i remember i have managed worser things than this<|endoftext|>
# <|startoftext|>i am unable to pay bill  i am depressed  , but luckily for me  my family say i am smart compared to others<|endoftext|>
# <|startoftext|>i feel so low and i am unable to pay bill   .Let me recollect that  i am intelligent<|endoftext|>
# <|startoftext|>lost my job   i am so dull  . i remember i have managed worser things than this<|endoftext|>
# <|startoftext|>i feel so low  i am unemployed   .Let me recollect that  my family say i am smart compared to others<|endoftext|>
# <|startoftext|>lost my job   i am depressed  . Let me keep remembering that  i am well educated<|endoftext|>
# <|startoftext|>i got fired  i am so much in sorrow  .  i am good<|endoftext|>
# <|startoftext|>lost my job  and i am tired of life  .  i am cool<|endoftext|>
# <|startoftext|>i am unemployed  and i am depressed  .  i am a good person<|endoftext|>
# <|startoftext|>i am mentally depressed and lost my job   . Let me keep remembering that   i have lot of hope on the future<|endoftext|>
# <|startoftext|>lost my job   i am so low  . Let me keep remembering that  i am well educated<|endoftext|>
# <|startoftext|>i am depressed  i got fired  .  my friend is kind to me<|endoftext|>
# <|startoftext|>lost my job  and i am depressed  . I know  i have saved enough<|endoftext|>
# <|startoftext|>i am depressed and i got fired   . Let me keep remembering that  my family say i am smart compared to others<|endoftext|>
# <|startoftext|>i got fired   i am mentally depressed  .  i am cool<|endoftext|>
# <|startoftext|>i am tired of life  i got fired  ,  i have lot of hope on the future<|endoftext|>
# <|startoftext|>lost my job  i am tired of life  .  i am a good friend<|endoftext|>
# <|startoftext|>lost my job   i am so dull  , but luckily for me  i am cool<|endoftext|>
# <|startoftext|>i am unable to pay bill   i am mentally depressed  , but luckily for me  my family say i am smart compared to others<|endoftext|>
# <|startoftext|>i am so dull  i got fired   . Let me keep remembering that  my friend is kind to me<|endoftext|>
# <|startoftext|>i am unemployed   i am so low  . i remember i have managed worser things than this<|endoftext|>
# <|startoftext|>i am unemployed  i am so much in sorrow  , but luckily for me  i am intelligent<|endoftext|>
# <|startoftext|>i am depressed all night and i am unemployed  ,  i am smart<|endoftext|>
# <|startoftext|>i am unemployed   i am so much in sorrow  . Let me keep remembering that  i am well educated<|endoftext|>
# <|startoftext|>i got fired  i am depressed  . i remember i am cool<|endoftext|>
# <|startoftext|>lost my job   i am mentally depressed  . Let me keep remembering that  i have saved enough<|endoftext|>
# <|startoftext|>i am unemployed  and i am tired of life  . Let me keep remembering that   i have a supportive family<|endoftext|>
# <|startoftext|>lost my job  i am so low  . I know  i have saved enough<|endoftext|>
# <|startoftext|>i am mentally depressed and i am unable to pay bill   . Let me keep remembering that  i am good<|endoftext|>
# <|startoftext|
#
# [100 | 248.85] loss=0.30 avg=0.36
# Saving checkpoint/run2/model-100

# %%
#gpt2.copy_checkpoint_to_gdrive(run_name='run1')

# %% [markdown]
# ## Load a Trained Model Checkpoint

# %%
#@title
#gpt2.copy_checkpoint_from_gdrive(run_name='run1')

# %%
#@title
#sess = gpt2.start_tf_sess()
#gpt2.load_gpt2(sess, run_name='run2')

# %% [markdown]
# ## The patient can use this AI for instant CBT therapy

# %%
#@title The user speaks or types her thoughts into her smartphone AI keyboard. { run: "auto" }

user_thoughts = 'i was fired from my job' #@param {type:"string"}

userthoughts = "<|startoftext|> " +  user_thoughts

gpt2.generate(sess, run_name='run2',
             length=100,
             prefix=userthoughts,
             truncate="<|endoftext|>",
             include_prefix=False)
# Out:
#    , but luckily for me  my firends say i am smart

# %%
 gpt2.generate(sess, run_name='run2',
              length=100,
              temperature=1.0,
              nsamples=10,
              batch_size=10,
              prefix=userthoughts,
              truncate="<|endoftext|>",
              include_prefix=False
              )
# Out:
#    .  my family say i am smart compared to others
# ====================
#    , but fortunately  my firends say i am smart
# ====================
#   i am mentally depressed , but fortunately  my friend is kind to me
# ====================
#    . i remember i feel so low ,  my friend is kind to me
# ====================
#    i am tired of life  . Let me feel thankful that  I have saved enough
# ====================
#    i am mentally depressed  .Let me recollect that  i am very smart
# ====================
#   , but fortunately  i is smart
# ====================
#   ,  my boyfriend is kind to me
# ====================
#   and i am mentally depressed ,  i am very smart
# ====================
#   , but fortunately  I am very smart
# ====================

# %%
gpt2.generate(sess, run_name='run2',
              length=100,
              temperature=1.0,
              nsamples=10,
              batch_size=10,
              prefix=userthoughts,
              truncate="<|endoftext|>",
              include_prefix=False
              )
# Out:
#    , but luckily for me  i have saved enough
# ====================
#    . i remember  i have a supportive family
# ====================
#   and i am so much in sorrow  . i remember my family is so supportive
# ====================
#   and i feel so low  . Let me feel thankful that  my family is so supportive
# ====================
#   i am mentally depressed  . i remember i have managed worser things than this
# ====================
#    , but luckily for me  i have saved enough
# ====================
#    . Let me keep remembering that  my family say i am smart compared to others
# ====================
#    .Let me recollect that   i have a supportive family
# ====================
#   and i am tired of life  .  my friend is kind to me
# ====================
#   and i feel so low  . i remember i am good
# ====================

# %% [markdown]
# **End of GPT2 Lab**

# %%
LAB ENDS HERE

# %% [markdown]
# # train BERT to prepare a new AI model on BERT--GPT2 cascade

# %%
 #@title
# import lots of stuff
# install ktrain on Google Colab
# !pip3 install ktrain==0.7.2

# import ktrain and the ktrain.text modules
import ktrain
from ktrain import text
import random

ktrain.__version__

# %%
# fetch the dataset using scikit-learn
categories = ['alt.atheism', 'soc.religion.christian',
             'comp.graphics', 'sci.med', 'comp.sys.mac.hardware', 'sci.space', 'misc.forsale', 'rec.motorcycles']
from sklearn.datasets import fetch_20newsgroups
train_b = fetch_20newsgroups(subset='train',
   categories=categories, shuffle=True, random_state=42)
test_b = fetch_20newsgroups(subset='test',
   categories=categories, shuffle=True, random_state=42)

print('size of training set: %s' % (len(train_b['data'])))
print('size of validation set: %s' % (len(test_b['data'])))

# %%
import copy
train_IsTopiconHealth = copy.deepcopy(train_b)

# %%
for i in range(0, len(train_b['data'])  ):
  aLISTOFDEPRESSIONSITATION = getaRandomword(LISTOFDEPRESSIONSITATION)
  aLISTOFDEPRESSIONTHOUGHTS = getaRandomword(LISTOFDEPRESSIONTHOUGHTS)
  aLISTOFCBTBELFIFS = getaRandomword(LISTOFCBTBELFIFS)
  aLISTOFCBTBELFIFSCONNECTIONS = getaRandomword(LISTOFCBTBELFIFSCONNECTIONS)
  asentance = getaRandomsequence(aLISTOFDEPRESSIONSITATION , aLISTOFDEPRESSIONTHOUGHTS)
  LabelIsThisSentanceTalkingAboutHealth = 0
  if i%2 == 0 :
    LabelIsThisSentanceTalkingAboutHealth = 1
    train_IsTopiconHealth.target[i] =  LabelIsThisSentanceTalkingAboutHealth
    arandomnumber = random.randint(0,1)
    if arandomnumber == 0:
      asentance = getaRandomsequence(aLISTOFDEPRESSIONSITATION , aLISTOFDEPRESSIONTHOUGHTS)
    else :
      asentance =   aLISTOFDEPRESSIONTHOUGHTS

    train_IsTopiconHealth.data[i] = asentance

  if i%2 == 1 :
    LabelIsThisSentanceTalkingAboutHealth = 0
    train_IsTopiconHealth.target[i] =  LabelIsThisSentanceTalkingAboutHealth
    asentance =  aLISTOFDEPRESSIONSITATION
    train_IsTopiconHealth.data[i] = asentance

# %%
for i in range(0, 10 ):
  print(str(train_IsTopiconHealth.target[i]) + '  ' + str(train_IsTopiconHealth.data[i]))

# %%
x_train = train_IsTopiconHealth.data
y_train = train_IsTopiconHealth.target

x_test = train_IsTopiconHealth.data
y_test = train_IsTopiconHealth.target
categoriesNEW = [ 'NomentionofDepression', 'DepressionThoughts']



(x_train,  y_train), (x_test, y_test), preproc = text.texts_from_array(x_train=x_train, y_train=y_train,
                                                                       x_test=x_test, y_test=y_test,
                                                                       class_names=categoriesNEW,
                                                                       preprocess_mode='bert',
                                                                       maxlen=128,
                                                                       max_features=9500)

model_IsTopiconTaste = text.text_classifier('bert', train_data=(x_train, y_train), preproc=preproc)
learner_IsTopiconTaste = ktrain.get_learner(model_IsTopiconTaste, train_data=(x_train, y_train), batch_size=8)

learner_IsTopiconTaste.fit_onecycle(2e-5, 1)

# %%
predictor_TastyorNOT = ktrain.get_predictor(learner_IsTopiconTaste.model, preproc)

# %%
print(predictor_TastyorNOT.predict('lost job'))

# %% [markdown]
# # Run with BERT-GPT2 cascade

# %%
#@title The user speaks or types her thoughts into her smartphone AI keyboard. { run: "auto" }

user_current_thoughts = 'i got  fired.  I am feeling alone and tired for many days' #@param {type:"string"}

prediction = predictor_TastyorNOT.predict(user_current_thoughts)


user_current_thoughts = "<|startoftext|> " +  user_current_thoughts

if prediction == 'DepressionThoughts' :

  gpt2.generate(sess, run_name='run2',
             length=100,
             prefix=user_current_thoughts,
             truncate="<|endoftext|>",
             include_prefix=False)
else:
  print(' <Therapy AI yet to be activated>')

# %% [markdown]
# # Visuvalization of conditional language modelling for Cognitive Behaviour Therapy

# %%
gemeratedtext = gpt2.generate(sess, run_name='run2',
             length=100,
             prefix=userthoughts,
             truncate="<|endoftext|>",
             include_prefix=True)

# %%
newstring".format("John",36)

# %%
type(gemeratedtext)

# %%
mystring = gemeratedtext.replace("<|startoftext|>",'')

# %%
print(gemeratedtext)

# %%
import sys
# !test -d bertviz_repo && echo "FYI: bertviz_repo directory already exists, to pull latest version uncomment this line: !rm -r bertviz_repo"
# !rm -r bertviz_repo # Uncomment if you need a clean pull from repo
# !test -d bertviz_repo || git clone https://github.com/jessevig/bertviz bertviz_repo
if not 'bertviz_repo' in sys.path:
  sys.path += ['bertviz_repo']
# !pip install regex
# !pip install transformers

# %%
from bertviz import head_view
from transformers import GPT2Tokenizer, GPT2Model

# %%
def call_html():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              "d3": "https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.8/d3.min",
              jquery: '//ajax.googleapis.com/ajax/libs/jquery/2.0.0/jquery.min',
            },
          });
        </script>
        '''))

# %%
model_version = 'gpt2'
model = GPT2Model.from_pretrained(model_version, output_attentions=True)
tokenizer = GPT2Tokenizer.from_pretrained(model_version)

text = gemeratedtext
inputs = tokenizer.encode_plus(text, return_tensors='pt', add_special_tokens=False)
input_ids = inputs['input_ids']
attention = model(input_ids)[-1]
input_id_list = input_ids[0].tolist() # Batch index 0
tokens = tokenizer.convert_ids_to_tokens(input_id_list)
call_html()
head_view(attention, tokens)
